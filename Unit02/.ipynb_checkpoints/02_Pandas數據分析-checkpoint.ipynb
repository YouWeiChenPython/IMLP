# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv('./data/grades.csv')

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# # Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df["國文"]
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.英文)
# Out:
# 0.16015801596684315

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis=1)

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df["加權"] = df.國文 + df.英文*2 + df.數學*2 + df.自然*2 + df.社會

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分   加權
# 0   劉俊安   9  10  15  10  13   57   92
# 1   胡玉華  10  10  10   8   9   47   75
# 2   黃淑婷  13  15   8  11  14   61   95
# 3   陳上紫  10  10   8   9  14   51   78
# 4   崔靜成  13  12  14  12  13   64  102
# ..  ...  ..  ..  ..  ..  ..  ...  ...
# 95  蔡佳燕   9  10   9  13  14   55   87
# 96  吳筱婷   8  10  14  10  15   57   91
# 97  陳家銘  14   9  11   8  12   54   82
# 98  李明威  15   9   8   9  15   56   82
# 99  農揚勇   9  11  12  12  10   54   89
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by="總級分", ascending=False).head()
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分   加權
# 80  施雅鈴  13  15  12  13  13   66  106
# 12  李正偉  11  15  11  14  15   66  106
# 54  陳怡潔  15  15   9  15  11   65  104
# 25  蔡亦瑄  13  13  14  13  12   65  105
# 57  胡淳茜  12  15  14  13  11   65  107

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by=["加權","總級分"], ascending=False)
df2
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分   加權
# 57  胡淳茜  12  15  14  13  11   65  107
# 83  李士賢  10  14  15  13  13   65  107
# 12  李正偉  11  15  11  14  15   66  106
# 80  施雅鈴  13  15  12  13  13   66  106
# 64  俞志峰   9  14  13  14  15   65  106
# ..  ...  ..  ..  ..  ..  ..  ...  ...
# 1   胡玉華  10  10  10   8   9   47   75
# 93  李曼夢  11   9  11   8   8   47   75
# 32  林建亨   9  11   8   8  11   47   74
# 7   林金鳳   8   9  10  10   8   45   74
# 18  梁慧君   9   8   8   8  12   45   69
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1,len(df2)+1)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分   加權
# 1  胡淳茜  12  15  14  13  11   65  107
# 2  李士賢  10  14  15  13  13   65  107
# 3  李正偉  11  15  11  14  15   66  106
# 4  施雅鈴  13  15  12  13  13   66  106
# 5  俞志峰   9  14  13  14  15   65  106

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df_math_15 = df[df.數學==15]
df_math_15.index = range(1, len(df_math_15)+1)
df_math_15
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分   加權
# 1   劉俊安   9  10  15  10  13   57   92
# 2   陳竹伯  10  12  15  10  14   61   98
# 3   詹威德  12  13  15  10  14   64  102
# 4   曾怡君  11  12  15  13  14   65  105
# 5   段冠廷   9   8  15  12  15   59   94
# 6   芮秋辛  11  10  15  10   8   54   89
# 7   林哲法  14   9  15  10  14   62   96
# 8   葉儀依   9  13  15   8  14   59   95
# 9   吳志遠  13  15  15   8   8   59   97
# 10  周育霖   9  12  15  13  12   61  101
# 11  李士賢  10  14  15  13  13   65  107
# 12  張雅彬  10  11  15  12   8   56   94
# 13  胡勝傑   8  11  15  10  15   59   95

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df_math_and_english_15 = df[(df.數學==15) & (df.英文==15)]
df_math_and_english_15.index = range(1, len(df_math_and_english_15)+1)
df_math_and_english_15
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  97

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df.drop('總級分', axis = 1)
# Out:
#      姓名  國文  英文  數學  自然  社會   加權
# 0   劉俊安   9  10  15  10  13   92
# 1   胡玉華  10  10  10   8   9   75
# 2   黃淑婷  13  15   8  11  14   95
# 3   陳上紫  10  10   8   9  14   78
# 4   崔靜成  13  12  14  12  13  102
# ..  ...  ..  ..  ..  ..  ..  ...
# 95  蔡佳燕   9  10   9  13  14   87
# 96  吳筱婷   8  10  14  10  15   91
# 97  陳家銘  14   9  11   8  12   82
# 98  李明威  15   9   8   9  15   82
# 99  農揚勇   9  11  12  12  10   89
#
# [100 rows x 7 columns]

# %%
df_test = df
df_test.drop('總級分', axis = 1, inplace = True)
df_test
# Out:
#      姓名  國文  英文  數學  自然  社會   加權
# 0   劉俊安   9  10  15  10  13   92
# 1   胡玉華  10  10  10   8   9   75
# 2   黃淑婷  13  15   8  11  14   95
# 3   陳上紫  10  10   8   9  14   78
# 4   崔靜成  13  12  14  12  13  102
# ..  ...  ..  ..  ..  ..  ..  ...
# 95  蔡佳燕   9  10   9  13  14   87
# 96  吳筱婷   8  10  14  10  15   91
# 97  陳家銘  14   9  11   8  12   82
# 98  李明威  15   9   8   9  15   82
# 99  農揚勇   9  11  12  12  10   89
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop('總級分', axis = 1, inplace = True)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會   加權
# 1  胡淳茜  12  15  14  13  11  107
# 2  李士賢  10  14  15  13  13  107
# 3  李正偉  11  15  11  14  15  106
# 4  施雅鈴  13  15  12  13  13  106
# 5  俞志峰   9  14  13  14  15  106

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2
# Out:
#       姓名  國文  英文  數學  自然  社會   加權
# 1    胡淳茜  12  15  14  13  11  107
# 2    李士賢  10  14  15  13  13  107
# 3    李正偉  11  15  11  14  15  106
# 4    施雅鈴  13  15  12  13  13  106
# 5    俞志峰   9  14  13  14  15  106
# ..   ...  ..  ..  ..  ..  ..  ...
# 96   胡玉華  10  10  10   8   9   75
# 97   李曼夢  11   9  11   8   8   75
# 98   林建亨   9  11   8   8  11   74
# 99   林金鳳   8   9  10  10   8   74
# 100  梁慧君   9   8   8   8  12   69
#
# [100 rows x 7 columns]

# %%
df2.drop(5).head()
# Out:
#     姓名  國文  英文  數學  自然  社會   加權
# 1  胡淳茜  12  15  14  13  11  107
# 2  李士賢  10  14  15  13  13  107
# 3  李正偉  11  15  11  14  15  106
# 4  施雅鈴  13  15  12  13  13  106
# 6  劉麗芬   8  14  14  14  14  106

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2[df2.姓名=='李士賢']
# Out:
#     姓名  國文  英文  數學  自然  社會   加權
# 2  李士賢  10  14  15  13  13  107

# %%
df2.drop(df2[df2.姓名=='李士賢'].index)
# Out:
#       姓名  國文  英文  數學  自然  社會   加權
# 1    胡淳茜  12  15  14  13  11  107
# 3    李正偉  11  15  11  14  15  106
# 4    施雅鈴  13  15  12  13  13  106
# 5    俞志峰   9  14  13  14  15  106
# 6    劉麗芬   8  14  14  14  14  106
# ..   ...  ..  ..  ..  ..  ..  ...
# 96   胡玉華  10  10  10   8   9   75
# 97   李曼夢  11   9  11   8   8   75
# 98   林建亨   9  11   8   8  11   74
# 99   林金鳳   8   9  10  10   8   74
# 100  梁慧君   9   8   8   8  12   69
#
# [99 rows x 7 columns]

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pdr.get_data_yahoo('AAPL')

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
# df = pd.read_csv('data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-08-08  27.092501  26.790001  26.879999  27.092501  112148800.0  25.446508
# 2016-08-09  27.235001  27.002501  27.057501  27.202499  105260800.0  25.549829
# 2016-08-10  27.225000  26.940001  27.177500  27.000000   96034000.0  25.359632
# 2016-08-11  27.232500  26.962500  27.129999  26.982500  109938000.0  25.343191
# 2016-08-12  27.110001  26.945000  26.945000  27.045000   74641600.0  25.401896

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-06-01   80.587502   79.302498   79.437500   80.462502   80791200.0
# 2020-06-02   80.860001   79.732498   80.187500   80.834999   87642800.0
# 2020-06-03   81.550003   80.574997   81.165001   81.279999  104491200.0
# 2020-06-04   81.404999   80.195000   81.097504   80.580002   87560400.0
# 2020-06-05   82.937500   80.807503   80.837502   82.875000  137250400.0
# ...                ...         ...         ...         ...          ...
# 2021-08-02  146.949997  145.250000  146.360001  145.520004   62880000.0
# 2021-08-03  148.039993  145.179993  145.809998  147.360001   64660800.0
# 2021-08-04  147.789993  146.279999  147.270004  146.949997   56368300.0
# 2021-08-05  147.839996  146.169998  146.979996  147.059998   46343200.0
# 2021-08-06  147.100006  145.630005  146.350006  146.139999   54126813.0
#
#              Adj Close
# Date
# 2020-06-01   79.923965
# 2020-06-02   80.293968
# 2020-06-03   80.735992
# 2020-06-04   80.040680
# 2020-06-05   82.320328
# ...                ...
# 2021-08-02  145.520004
# 2021-08-03  147.360001
# 2021-08-04  146.949997
# 2021-08-05  147.059998
# 2021-08-06  146.139999
#
# [300 rows x 6 columns]

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.rolling(20).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x = close[:-1]
len(x)
# Out:
# 299

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.97097729, -1.4363289 ,  1.80361266],
#        [ 0.50630511,  0.3857773 , -0.83730831],
#        [-0.01607771, -0.0686879 , -1.37294396],
#        [-0.27027139, -1.48455695, -1.47229937]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.970977 -1.436329  1.803613
# 1  0.506305  0.385777 -0.837308
# 2 -0.016078 -0.068688 -1.372944
# 3 -0.270271 -1.484557 -1.472299

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0 -0.106512  2.112982  0.231693
# 1  0.096949  0.097879 -0.178424
# 2  0.637242 -1.642435  0.127530

# %%
df4 = pd.concat([df2,df3], axis = 0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.970977 -1.436329  1.803613
# 1  0.506305  0.385777 -0.837308
# 2 -0.016078 -0.068688 -1.372944
# 3 -0.270271 -1.484557 -1.472299
# 0 -0.106512  2.112982  0.231693
# 1  0.096949  0.097879 -0.178424
# 2  0.637242 -1.642435  0.127530

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(len(df4.index))

# %%
df4
# Out:
#           A         B         C
# 0 -0.970977 -1.436329  1.803613
# 1  0.506305  0.385777 -0.837308
# 2 -0.016078 -0.068688 -1.372944
# 3 -0.270271 -1.484557 -1.472299
# 4 -0.106512  2.112982  0.231693
# 5  0.096949  0.097879 -0.178424
# 6  0.637242 -1.642435  0.127530

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2,df3], axis = 1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.970977 -1.436329  1.803613 -0.106512  2.112982  0.231693
# 1  0.506305  0.385777 -0.837308  0.096949  0.097879 -0.178424
# 2 -0.016078 -0.068688 -1.372944  0.637242 -1.642435  0.127530
# 3 -0.270271 -1.484557 -1.472299       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('data/names.csv', names=['姓名'])

# %%
df_names
# Out:
#      姓名
# 0   羅雅慧
# 1   王紹尹
# 2   黃季坤
# 3   許正書
# 4   張鈞蓮
# ..  ...
# 95  陳君生
# 96  曾桂甫
# 97  林欣怡
# 98  林佳霖
# 99  胡筱芸
#
# [100 rows x 1 columns]

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades.to_csv('data/grade2.csv', index = 0)

# %%
df_grades = pd.read_csv('data/grade2.csv')
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0    8  11  14  11  12
# 1    8   6  13  12   8
# 2    6  13  15   6  13
# 3   15   8   9   6   8
# 4    8   6   9  15  15
# ..  ..  ..  ..  ..  ..
# 95  15   6  12   7  10
# 96   8   8   6  13   8
# 97   7   8   7  15   9
# 98  14   6   6  15   6
# 99   6   6  14   6   7
#
# [100 rows x 5 columns]

# %%
df_score = pd.concat([df_names, df_grades], axis=1)

# %%
df_score
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧   8  11  14  11  12
# 1   王紹尹   8   6  13  12   8
# 2   黃季坤   6  13  15   6  13
# 3   許正書  15   8   9   6   8
# 4   張鈞蓮   8   6   9  15  15
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生  15   6  12   7  10
# 96  曾桂甫   8   8   6  13   8
# 97  林欣怡   7   8   7  15   9
# 98  林佳霖  14   6   6  15   6
# 99  胡筱芸   6   6  14   6   7
#
# [100 rows x 6 columns]
